# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitiude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
        
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=974fd867c22fe5fa732db5571be46944

# %%
# Create an empty list ot hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in set of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that data loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | big spring
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | wanning
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | mount gambier
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | jvari
# Processing Record 12 of Set 1 | polyarnyy
# Processing Record 13 of Set 1 | trairi
# Processing Record 14 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 15 of Set 1 | anyksciai
# Processing Record 16 of Set 1 | rosetta
# Processing Record 17 of Set 1 | sola
# Processing Record 18 of Set 1 | mineiros
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | acopiara
# Processing Record 21 of Set 1 | constitucion
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | babu
# Processing Record 24 of Set 1 | pangody
# Processing Record 25 of Set 1 | la ronge
# Processing Record 26 of Set 1 | sao joao da barra
# Processing Record 27 of Set 1 | porto novo
# Processing Record 28 of Set 1 | jega
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | ranong
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | otradnyy
# Processing Record 38 of Set 1 | forestville
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | manokwari
# Processing Record 44 of Set 1 | kaeo
# Processing Record 45 of Set 1 | padang
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | cabo san lucas
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 2 | bacungan
# Processing Record 3 of Set 2 | betong
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | gunnedah
# Processing Record 6 of Set 2 | mahibadhoo
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | hervey bay
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | taltal
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | uchiza
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | puerto escondido
# Processing Record 17 of Set 2 | williams lake
# Processing Record 18 of Set 2 | san alberto
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | venkatagiri
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | lighthouse point
# Processing Record 24 of Set 2 | pozo colorado
# Processing Record 25 of Set 2 | yumen
# Processing Record 26 of Set 2 | talnakh
# Processing Record 27 of Set 2 | tres picos
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | yellowknife
# Processing Record 30 of Set 2 | manzanillo
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | jardim
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | antalaha
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | flinders
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | hami
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | arman
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | orotukan
# Processing Record 5 of Set 3 | bagotville
# Processing Record 6 of Set 3 | naze
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | tautira
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | rabo de peixe
# Processing Record 11 of Set 3 | lompoc
# Processing Record 12 of Set 3 | xichang
# Processing Record 13 of Set 3 | kotido
# Processing Record 14 of Set 3 | narsaq
# Processing Record 15 of Set 3 | vardo
# Processing Record 16 of Set 3 | belaya gora
# Processing Record 17 of Set 3 | camacha
# Processing Record 18 of Set 3 | bathsheba
# Processing Record 19 of Set 3 | praia
# Processing Record 20 of Set 3 | tromso
# Processing Record 21 of Set 3 | pauini
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | kahului
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | uvira
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | umm lajj
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | ust-kuyga
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | hay river
# Processing Record 35 of Set 3 | bonavista
# Processing Record 36 of Set 3 | moranbah
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | nanortalik
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | kiunga
# Processing Record 42 of Set 3 | krasnyy yar
# Processing Record 43 of Set 3 | avarua
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | riberalta
# Processing Record 46 of Set 3 | arona
# Processing Record 47 of Set 3 | saint-philippe
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | lahaina
# Processing Record 1 of Set 4 | akyab
# Processing Record 2 of Set 4 | talawdi
# City not found. Skipping...
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 4 | chapais
# Processing Record 6 of Set 4 | fairbanks
# Processing Record 7 of Set 4 | nikolskoye
# Processing Record 8 of Set 4 | nortelandia
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | iralaya
# Processing Record 12 of Set 4 | artyom
# Processing Record 13 of Set 4 | dingle
# Processing Record 14 of Set 4 | saint-pierre
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | atuona
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | monrovia
# Processing Record 19 of Set 4 | iqaluit
# Processing Record 20 of Set 4 | jiwani
# Processing Record 21 of Set 4 | maniitsoq
# Processing Record 22 of Set 4 | porto santo
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | nerchinskiy zavod
# Processing Record 26 of Set 4 | muscat
# Processing Record 27 of Set 4 | thinadhoo
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | broken hill
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | bayshore gardens
# Processing Record 34 of Set 4 | tessalit
# Processing Record 35 of Set 4 | barranca
# Processing Record 36 of Set 4 | poso
# Processing Record 37 of Set 4 | itupiranga
# Processing Record 38 of Set 4 | ribeira grande
# Processing Record 39 of Set 4 | hasaki
# Processing Record 40 of Set 4 | bressanone
# Processing Record 41 of Set 4 | kutum
# Processing Record 42 of Set 4 | verkhnevilyuysk
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 4 | hearst
# Processing Record 46 of Set 4 | qorveh
# Processing Record 47 of Set 4 | koshurnikovo
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | emba
# Processing Record 50 of Set 4 | kampong thum
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | wattegama
# Processing Record 3 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 5 | copiapo
# Processing Record 5 of Set 5 | lemay
# Processing Record 6 of Set 5 | show low
# Processing Record 7 of Set 5 | inirida
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | jhansi
# Processing Record 10 of Set 5 | grand gaube
# Processing Record 11 of Set 5 | chebsara
# Processing Record 12 of Set 5 | tasiilaq
# Processing Record 13 of Set 5 | broome
# Processing Record 14 of Set 5 | ratnagiri
# Processing Record 15 of Set 5 | fukue
# Processing Record 16 of Set 5 | yulara
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | rock springs
# Processing Record 19 of Set 5 | atlantis
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | neuquen
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | shebalino
# Processing Record 24 of Set 5 | karasjok
# Processing Record 25 of Set 5 | sayyan
# Processing Record 26 of Set 5 | eyl
# Processing Record 27 of Set 5 | tenno
# Processing Record 28 of Set 5 | jalu
# Processing Record 29 of Set 5 | kushmurun
# Processing Record 30 of Set 5 | faanui
# Processing Record 31 of Set 5 | cap malheureux
# Processing Record 32 of Set 5 | veraval
# Processing Record 33 of Set 5 | brzeg dolny
# Processing Record 34 of Set 5 | dudinka
# Processing Record 35 of Set 5 | hastings
# Processing Record 36 of Set 5 | piacabucu
# Processing Record 37 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 5 | zwedru
# Processing Record 39 of Set 5 | beatrice
# Processing Record 40 of Set 5 | busayra
# Processing Record 41 of Set 5 | hobyo
# Processing Record 42 of Set 5 | vila
# Processing Record 43 of Set 5 | grand-lahou
# Processing Record 44 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 5 | westport
# Processing Record 46 of Set 5 | alyangula
# Processing Record 47 of Set 5 | vila franca do campo
# Processing Record 48 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 5 | utica
# Processing Record 50 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 6 | baijiantan
# Processing Record 2 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 6 | bestobe
# Processing Record 4 of Set 6 | mayumba
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | tiksi
# Processing Record 10 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 6 | ussel
# Processing Record 12 of Set 6 | ugoofaaru
# Processing Record 13 of Set 6 | saint anthony
# Processing Record 14 of Set 6 | hambantota
# Processing Record 15 of Set 6 | burgeo
# Processing Record 16 of Set 6 | byron bay
# Processing Record 17 of Set 6 | itarema
# Processing Record 18 of Set 6 | bohicon
# Processing Record 19 of Set 6 | turukhansk
# Processing Record 20 of Set 6 | aklavik
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | thompson
# Processing Record 23 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | ballina
# Processing Record 26 of Set 6 | north platte
# Processing Record 27 of Set 6 | garowe
# Processing Record 28 of Set 6 | davila
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | severnyy
# Processing Record 31 of Set 6 | sambava
# Processing Record 32 of Set 6 | baturaja
# Processing Record 33 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 6 | asyut
# Processing Record 35 of Set 6 | korla
# Processing Record 36 of Set 6 | sabzevar
# Processing Record 37 of Set 6 | buala
# Processing Record 38 of Set 6 | banyuwangi
# Processing Record 39 of Set 6 | kashmor
# Processing Record 40 of Set 6 | dikson
# Processing Record 41 of Set 6 | nacala
# Processing Record 42 of Set 6 | shimoda
# Processing Record 43 of Set 6 | matara
# Processing Record 44 of Set 6 | adrar
# Processing Record 45 of Set 6 | bolshaya sosnova
# Processing Record 46 of Set 6 | necochea
# Processing Record 47 of Set 6 | sterling
# Processing Record 48 of Set 6 | marawi
# Processing Record 49 of Set 6 | khandyga
# Processing Record 50 of Set 6 | kismayo
# Processing Record 1 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 7 | los llanos de aridane
# Processing Record 3 of Set 7 | conceicao do araguaia
# Processing Record 4 of Set 7 | ngaoundere
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | coihaique
# Processing Record 7 of Set 7 | feicheng
# Processing Record 8 of Set 7 | bati
# Processing Record 9 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | xinzhi
# Processing Record 12 of Set 7 | nome
# Processing Record 13 of Set 7 | iranshahr
# Processing Record 14 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 7 | la palma
# Processing Record 16 of Set 7 | ruston
# Processing Record 17 of Set 7 | lorengau
# Processing Record 18 of Set 7 | gat
# Processing Record 19 of Set 7 | vung tau
# Processing Record 20 of Set 7 | tenenkou
# Processing Record 21 of Set 7 | kuching
# Processing Record 22 of Set 7 | leningradskiy
# Processing Record 23 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 7 | shenjiamen
# Processing Record 25 of Set 7 | uusikaupunki
# Processing Record 26 of Set 7 | kalemie
# Processing Record 27 of Set 7 | inhambane
# Processing Record 28 of Set 7 | eersel
# Processing Record 29 of Set 7 | puerto del rosario
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | kharan
# Processing Record 32 of Set 7 | mackay
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | taoudenni
# Processing Record 35 of Set 7 | ostrovnoy
# Processing Record 36 of Set 7 | pedro carbo
# Processing Record 37 of Set 7 | wiarton
# Processing Record 38 of Set 7 | amahai
# Processing Record 39 of Set 7 | presidencia roque saenz pena
# Processing Record 40 of Set 7 | marsh harbour
# Processing Record 41 of Set 7 | alta floresta
# Processing Record 42 of Set 7 | batagay-alyta
# Processing Record 43 of Set 7 | tatarsk
# Processing Record 44 of Set 7 | barra do corda
# Processing Record 45 of Set 7 | galle
# Processing Record 46 of Set 7 | faya
# Processing Record 47 of Set 7 | asau
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | san carlos de bariloche
# Processing Record 50 of Set 7 | miracema do tocantins
# Processing Record 1 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | hohhot
# Processing Record 4 of Set 8 | kungurtug
# Processing Record 5 of Set 8 | cap-aux-meules
# Processing Record 6 of Set 8 | villa bruzual
# Processing Record 7 of Set 8 | san lawrenz
# Processing Record 8 of Set 8 | sakakah
# Processing Record 9 of Set 8 | owando
# Processing Record 10 of Set 8 | havelock
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | irpa irpa
# Processing Record 14 of Set 8 | buzmeyin
# Processing Record 15 of Set 8 | alekseyevka
# Processing Record 16 of Set 8 | egvekinot
# Processing Record 17 of Set 8 | dakar
# Processing Record 18 of Set 8 | filadelfia
# Processing Record 19 of Set 8 | dolores
# Processing Record 20 of Set 8 | sur
# Processing Record 21 of Set 8 | smithers
# Processing Record 22 of Set 8 | acapulco
# Processing Record 23 of Set 8 | zalantun
# Processing Record 24 of Set 8 | te anau
# Processing Record 25 of Set 8 | sorland
# Processing Record 26 of Set 8 | grindavik
# Processing Record 27 of Set 8 | kaka
# Processing Record 28 of Set 8 | lima
# Processing Record 29 of Set 8 | xiaoweizhai
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | wagar
# Processing Record 32 of Set 8 | homer
# Processing Record 33 of Set 8 | obidos
# Processing Record 34 of Set 8 | bar harbor
# Processing Record 35 of Set 8 | alice springs
# Processing Record 36 of Set 8 | peyima
# Processing Record 37 of Set 8 | kiama
# Processing Record 38 of Set 8 | bosaso
# Processing Record 39 of Set 8 | iquitos
# Processing Record 40 of Set 8 | hauterive
# Processing Record 41 of Set 8 | champerico
# Processing Record 42 of Set 8 | zeya
# Processing Record 43 of Set 8 | diego de almagro
# Processing Record 44 of Set 8 | neiafu
# Processing Record 45 of Set 8 | hebi
# Processing Record 46 of Set 8 | caravelas
# Processing Record 47 of Set 8 | coffs harbour
# Processing Record 48 of Set 8 | bubaque
# Processing Record 49 of Set 8 | mweka
# Processing Record 50 of Set 8 | dubbo
# Processing Record 1 of Set 9 | agadez
# Processing Record 2 of Set 9 | ambanja
# Processing Record 3 of Set 9 | norilsk
# Processing Record 4 of Set 9 | curillo
# Processing Record 5 of Set 9 | bonoua
# Processing Record 6 of Set 9 | muroto
# Processing Record 7 of Set 9 | cedeno
# Processing Record 8 of Set 9 | maraa
# Processing Record 9 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | suluq
# Processing Record 11 of Set 9 | caloundra
# Processing Record 12 of Set 9 | apricena
# Processing Record 13 of Set 9 | atambua
# Processing Record 14 of Set 9 | monte alegre
# Processing Record 15 of Set 9 | san rafael
# Processing Record 16 of Set 9 | napanee
# Processing Record 17 of Set 9 | konokovo
# Processing Record 18 of Set 9 | deputatskiy
# Processing Record 19 of Set 9 | mount pleasant
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | pangnirtung
# Processing Record 22 of Set 9 | fallon
# Processing Record 23 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 9 | ionia
# Processing Record 25 of Set 9 | nouadhibou
# Processing Record 26 of Set 9 | bosobolo
# Processing Record 27 of Set 9 | yanam
# Processing Record 28 of Set 9 | duluth
# Processing Record 29 of Set 9 | ejura
# Processing Record 30 of Set 9 | aden
# Processing Record 31 of Set 9 | haapiti
# Processing Record 32 of Set 9 | san quintin
# Processing Record 33 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 34 of Set 9 | askiz
# Processing Record 35 of Set 9 | khuzdar
# Processing Record 36 of Set 9 | samfya
# Processing Record 37 of Set 9 | pemangkat
# Processing Record 38 of Set 9 | alappuzha
# Processing Record 39 of Set 9 | vao
# Processing Record 40 of Set 9 | odesskoye
# Processing Record 41 of Set 9 | meilu
# City not found. Skipping...
# Processing Record 42 of Set 9 | khilok
# Processing Record 43 of Set 9 | muswellbrook
# Processing Record 44 of Set 9 | otradnoye
# Processing Record 45 of Set 9 | nizhnevartovsk
# Processing Record 46 of Set 9 | port-gentil
# Processing Record 47 of Set 9 | ambato
# Processing Record 48 of Set 9 | zaraza
# Processing Record 49 of Set 9 | yellapur
# Processing Record 50 of Set 9 | danville
# Processing Record 1 of Set 10 | nangong
# Processing Record 2 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 10 | roma
# Processing Record 4 of Set 10 | mago
# Processing Record 5 of Set 10 | okitipupa
# Processing Record 6 of Set 10 | belmonte
# Processing Record 7 of Set 10 | fort nelson
# Processing Record 8 of Set 10 | krasnoselkup
# Processing Record 9 of Set 10 | khorixas
# Processing Record 10 of Set 10 | kandrian
# Processing Record 11 of Set 10 | goundam
# Processing Record 12 of Set 10 | nemuro
# Processing Record 13 of Set 10 | krasnoye
# Processing Record 14 of Set 10 | nelson bay
# Processing Record 15 of Set 10 | nybro
# Processing Record 16 of Set 10 | limon
# Processing Record 17 of Set 10 | bull savanna
# Processing Record 18 of Set 10 | humaita
# Processing Record 19 of Set 10 | biak
# Processing Record 20 of Set 10 | araouane
# Processing Record 21 of Set 10 | tuatapere
# Processing Record 22 of Set 10 | pesnica pri mariboru
# Processing Record 23 of Set 10 | urucui
# Processing Record 24 of Set 10 | kultuk
# Processing Record 25 of Set 10 | mecca
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | mabaruma
# Processing Record 28 of Set 10 | jazzin
# City not found. Skipping...
# Processing Record 29 of Set 10 | sao gabriel da cachoeira
# Processing Record 30 of Set 10 | kloulklubed
# Processing Record 31 of Set 10 | manga
# Processing Record 32 of Set 10 | kamenka
# Processing Record 33 of Set 10 | teguldet
# Processing Record 34 of Set 10 | brae
# Processing Record 35 of Set 10 | ilulissat
# Processing Record 36 of Set 10 | kargasok
# Processing Record 37 of Set 10 | sarab
# Processing Record 38 of Set 10 | arlit
# Processing Record 39 of Set 10 | patiala
# Processing Record 40 of Set 10 | russell
# Processing Record 41 of Set 10 | port lincoln
# Processing Record 42 of Set 10 | jasper
# Processing Record 43 of Set 10 | lae
# Processing Record 44 of Set 10 | japura
# Processing Record 45 of Set 10 | asbest
# Processing Record 46 of Set 10 | bose
# Processing Record 47 of Set 10 | atar
# Processing Record 48 of Set 10 | ihosy
# Processing Record 49 of Set 10 | corner brook
# Processing Record 50 of Set 10 | nalut
# Processing Record 1 of Set 11 | beaverlodge
# Processing Record 2 of Set 11 | taikang
# Processing Record 3 of Set 11 | yuncheng
# Processing Record 4 of Set 11 | vilhena
# Processing Record 5 of Set 11 | haian
# Processing Record 6 of Set 11 | puerto maldonado
# Processing Record 7 of Set 11 | itoman
# Processing Record 8 of Set 11 | marataizes
# Processing Record 9 of Set 11 | ucluelet
# Processing Record 10 of Set 11 | oussouye
# Processing Record 11 of Set 11 | kariba
# Processing Record 12 of Set 11 | christchurch
# Processing Record 13 of Set 11 | ust-maya
# Processing Record 14 of Set 11 | el porvenir
# Processing Record 15 of Set 11 | grootfontein
# Processing Record 16 of Set 11 | vanimo
# Processing Record 17 of Set 11 | miraflores
# Processing Record 18 of Set 11 | mwense
# Processing Record 19 of Set 11 | rudnya
# Processing Record 20 of Set 11 | xicotencatl
# Processing Record 21 of Set 11 | conde
# Processing Record 22 of Set 11 | duns
# Processing Record 23 of Set 11 | canutama
# Processing Record 24 of Set 11 | takoradi
# Processing Record 25 of Set 11 | lavrentiya
# Processing Record 26 of Set 11 | copperas cove
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | cody
# Processing Record 29 of Set 11 | dandong
# Processing Record 30 of Set 11 | vostok
# Processing Record 31 of Set 11 | iquique
# Processing Record 32 of Set 11 | lubao
# Processing Record 33 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 34 of Set 11 | sierre
# Processing Record 35 of Set 11 | antalya
# Processing Record 36 of Set 11 | avera
# Processing Record 37 of Set 11 | rayagada
# Processing Record 38 of Set 11 | mattru
# Processing Record 39 of Set 11 | phuket
# Processing Record 40 of Set 11 | belaya kholunitsa
# Processing Record 41 of Set 11 | qiongshan
# Processing Record 42 of Set 11 | fundata
# Processing Record 43 of Set 11 | trincomalee
# Processing Record 44 of Set 11 | takapau
# Processing Record 45 of Set 11 | genc
# Processing Record 46 of Set 11 | huilong
# Processing Record 47 of Set 11 | ekhabi
# Processing Record 48 of Set 11 | sorochinsk
# Processing Record 49 of Set 11 | sao paulo de olivenca
# Processing Record 50 of Set 11 | fairlie
# Processing Record 1 of Set 12 | drummondville
# Processing Record 2 of Set 12 | karratha
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | dagana
# Processing Record 5 of Set 12 | ola
# Processing Record 6 of Set 12 | lamar
# Processing Record 7 of Set 12 | komsomolskiy
# Processing Record 8 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 12 | dalbandin
# Processing Record 10 of Set 12 | yakeshi
# Processing Record 11 of Set 12 | minyar
# Processing Record 12 of Set 12 | kenai
# Processing Record 13 of Set 12 | jacareacanga
# Processing Record 14 of Set 12 | natal
# Processing Record 15 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 16 of Set 12 | santiago del estero
# Processing Record 17 of Set 12 | mehamn
# Processing Record 18 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 12 | labuhan
# Processing Record 20 of Set 12 | alcudia
# Processing Record 21 of Set 12 | sint-gillis-waas
# Processing Record 22 of Set 12 | abu samrah
# Processing Record 23 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 12 | saldus
# Processing Record 25 of Set 12 | zile
# Processing Record 26 of Set 12 | port keats
# Processing Record 27 of Set 12 | buenaventura
# Processing Record 28 of Set 12 | skelleftea
# Processing Record 29 of Set 12 | tuchkovo
# Processing Record 30 of Set 12 | norrtalje
# Processing Record 31 of Set 12 | sioux lookout
# Processing Record 32 of Set 12 | karpogory
# Processing Record 33 of Set 12 | shentala
# Processing Record 34 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 12 | sidi ali
# Processing Record 36 of Set 12 | khoy
# Processing Record 37 of Set 12 | etah
# Processing Record 38 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 39 of Set 12 | madona
# Processing Record 40 of Set 12 | atlantic beach
# Processing Record 41 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 12 | sungaipenuh
# Processing Record 43 of Set 12 | nishihara
# Processing Record 44 of Set 12 | taitung
# Processing Record 45 of Set 12 | cranbrook
# Processing Record 46 of Set 12 | szilvasvarad
# Processing Record 47 of Set 12 | muzhi
# Processing Record 48 of Set 12 | todos santos
# Processing Record 49 of Set 12 | aktash
# Processing Record 50 of Set 12 | murzzuschlag
# Processing Record 1 of Set 13 | birin
# Processing Record 2 of Set 13 | kashi
# Processing Record 3 of Set 13 | novopskov
# Processing Record 4 of Set 13 | skjervoy
# Processing Record 5 of Set 13 | moree
# Processing Record 6 of Set 13 | bengkalis
# City not found. Skipping...
# Processing Record 7 of Set 13 | nadym
# Processing Record 8 of Set 13 | khuzhir
# Processing Record 9 of Set 13 | unguia
# Processing Record 10 of Set 13 | beya
# Processing Record 11 of Set 13 | lazarev
# Processing Record 12 of Set 13 | chicama
# Processing Record 13 of Set 13 | guilin
# Processing Record 14 of Set 13 | otjiwarongo
# Processing Record 15 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 16 of Set 13 | okha
# Processing Record 17 of Set 13 | voznesenskoye
# Processing Record 18 of Set 13 | sampit
# Processing Record 19 of Set 13 | nova olimpia
# Processing Record 20 of Set 13 | tarauaca
# Processing Record 21 of Set 13 | andalan
# Processing Record 22 of Set 13 | port moresby
# Processing Record 23 of Set 13 | raudeberg
# Processing Record 24 of Set 13 | tabou
# Processing Record 25 of Set 13 | koson
# Processing Record 26 of Set 13 | warrington
# Processing Record 27 of Set 13 | kishapu
# Processing Record 28 of Set 13 | dalvik
# Processing Record 29 of Set 13 | rincon
# Processing Record 30 of Set 13 | winnemucca
# Processing Record 31 of Set 13 | poum
# Processing Record 32 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 33 of Set 13 | meulaboh
# Processing Record 34 of Set 13 | tarbagatay
# Processing Record 35 of Set 13 | igrim
# Processing Record 36 of Set 13 | boyuibe
# Processing Record 37 of Set 13 | lebanon
# Processing Record 38 of Set 13 | redondo
# Processing Record 39 of Set 13 | lichinga
# Processing Record 40 of Set 13 | inuvik
# Processing Record 41 of Set 13 | dunedin
# Processing Record 42 of Set 13 | hare bay
# Processing Record 43 of Set 13 | vila velha
# Processing Record 44 of Set 13 | kyrksaeterora
# Processing Record 45 of Set 13 | druzhba
# Processing Record 46 of Set 13 | lyngseidet
# Processing Record 47 of Set 13 | port blair
# Processing Record 48 of Set 13 | alpena
# Processing Record 49 of Set 13 | tezu
# Processing Record 50 of Set 13 | santa marta
# Processing Record 1 of Set 14 | tiszakecske
# Processing Record 2 of Set 14 | zinder
# Processing Record 3 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 14 | mustasaari
# Processing Record 5 of Set 14 | weligama
# Processing Record 6 of Set 14 | tual
# Processing Record 7 of Set 14 | danilov
# Processing Record 8 of Set 14 | bandar-e lengeh
# Processing Record 9 of Set 14 | funtua
# Processing Record 10 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 14 | vestmannaeyjar
# Processing Record 12 of Set 14 | biltine
# Processing Record 13 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 14 | yarmouth
# Processing Record 15 of Set 14 | kemijarvi
# Processing Record 16 of Set 14 | ler
# Processing Record 17 of Set 14 | arandis
# Processing Record 18 of Set 14 | sira
# Processing Record 19 of Set 14 | maningrida
# Processing Record 20 of Set 14 | ariquemes
# Processing Record 21 of Set 14 | marzuq
# Processing Record 22 of Set 14 | shangqiu
# Processing Record 23 of Set 14 | okhotsk
# Processing Record 24 of Set 14 | ljungby
# Processing Record 25 of Set 14 | altay
# Processing Record 26 of Set 14 | raduzhnyy
# Processing Record 27 of Set 14 | san benito
# Processing Record 28 of Set 14 | makakilo city
# Processing Record 29 of Set 14 | safaga
# Processing Record 30 of Set 14 | keetmanshoop
# Processing Record 31 of Set 14 | namatanai
# Processing Record 32 of Set 14 | kropotkin
# Processing Record 33 of Set 14 | aksarka
# Processing Record 34 of Set 14 | aswan
# Processing Record 35 of Set 14 | muros
# Processing Record 36 of Set 14 | neepawa
# Processing Record 37 of Set 14 | hirara
# Processing Record 38 of Set 14 | camocim
# Processing Record 39 of Set 14 | kovdor
# Processing Record 40 of Set 14 | magadan
# Processing Record 41 of Set 14 | perni
# Processing Record 42 of Set 14 | san jose
# Processing Record 43 of Set 14 | athmallik
# Processing Record 44 of Set 14 | port hedland
# Processing Record 45 of Set 14 | bonthe
# Processing Record 46 of Set 14 | kamiiso
# Processing Record 47 of Set 14 | balabac
# Processing Record 48 of Set 14 | carbonia
# Processing Record 49 of Set 14 | virginia beach
# Processing Record 50 of Set 14 | charters towers
# Processing Record 1 of Set 15 | abha
# Processing Record 2 of Set 15 | cabedelo
# Processing Record 3 of Set 15 | hofn
# Processing Record 4 of Set 15 | flin flon
# Processing Record 5 of Set 15 | strani
# Processing Record 6 of Set 15 | sao felix do xingu
# Processing Record 7 of Set 15 | shieli
# Processing Record 8 of Set 15 | prince rupert
# Processing Record 9 of Set 15 | comlosu mare
# Processing Record 10 of Set 15 | montepuez
# Processing Record 11 of Set 15 | ambilobe
# Processing Record 12 of Set 15 | acarau
# Processing Record 13 of Set 15 | ulagan
# Processing Record 14 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 15 | beloha
# Processing Record 16 of Set 15 | kijang
# Processing Record 17 of Set 15 | seddon
# Processing Record 18 of Set 15 | najran
# Processing Record 19 of Set 15 | surgut
# Processing Record 20 of Set 15 | odweyne
# Processing Record 21 of Set 15 | kingston
# Processing Record 22 of Set 15 | ayan
# Processing Record 23 of Set 15 | bambanglipuro
# Processing Record 24 of Set 15 | muli
# Processing Record 25 of Set 15 | turayf
# Processing Record 26 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 27 of Set 15 | horqueta
# Processing Record 28 of Set 15 | uige
# Processing Record 29 of Set 15 | honjo
# Processing Record 30 of Set 15 | dauphin
# Processing Record 31 of Set 15 | carballo
# Processing Record 32 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 15 | moerai
# Processing Record 34 of Set 15 | cedar rapids
# Processing Record 35 of Set 15 | clarence town
# Processing Record 36 of Set 15 | brigantine
# Processing Record 37 of Set 15 | qeshm
# Processing Record 38 of Set 15 | gorontalo
# Processing Record 39 of Set 15 | la libertad
# Processing Record 40 of Set 15 | kununurra
# Processing Record 41 of Set 15 | obera
# Processing Record 42 of Set 15 | skibbereen
# Processing Record 43 of Set 15 | salta
# Processing Record 44 of Set 15 | ipora
# Processing Record 45 of Set 15 | litovko
# Processing Record 46 of Set 15 | lethem
# Processing Record 47 of Set 15 | islahiye
# Processing Record 48 of Set 15 | kouroussa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Big Spring      US  32.25 -101.48     93.20        10           1
# 1      Esperance      AU -33.87  121.90     55.40       100           0
# 2        Wanning      CN  18.80  110.40     78.21        85         100
# 3   Punta Arenas      CL -53.15  -70.92     48.20        57          20
# 4         Bethel      US  41.37  -73.41     59.00        47          90
# 5  Mount Gambier      AU -37.83  140.77     60.80        63          65
# 6        Rikitea      PF -23.12 -134.97     74.17        77           8
# 7     Butaritari      KI   3.07  172.79     81.03        74          23
# 8          Jvari      GE  42.72   42.05     62.10        41           2
# 9      Polyarnyy      RU  69.20   33.45     41.00       100          75
#
#    Wind Speed Current Description
# 0       13.87           clear sky
# 1        4.70           clear sky
# 2       16.31     overcast clouds
# 3       10.29          few clouds
# 4        4.70     overcast clouds
# 5       13.87       broken clouds
# 6       10.80           clear sky
# 7       12.73          few clouds
# 8        5.01           clear sky
# 9        2.24       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
